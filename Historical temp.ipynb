# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
sns.set(style='white', palette='tab10')
# Out:
# /opt/miniconda3/envs/powergenome/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
df = pd.read_csv('GLB.Ts+dSST.csv', skiprows=1, index_col=0)

# %%
df.loc[:, "J-D"].plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
temp_df = df[["J-D"]]
temp_df["datetime"] = pd.to_datetime(temp_df.index, format="%Y")
temp_df = temp_df.rename(columns={"J-D": "temp"})
temp_df.to_csv("annual_historical_temps.csv", index=False)
# Out:
# /var/folders/25/grw_c5gn4vs3x3rvzj1clw4c0000gn/T/ipykernel_11404/1245718961.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df["datetime"] = pd.to_datetime(temp_df.index, format="%Y")
