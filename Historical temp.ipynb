# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
sns.set(style='white', palette='tab10')

# %%
df = pd.read_csv('igiss_al_gl_m.txt', header=None, skiprows=3, index_col=0, 
                 delimiter=r"\s+")

# %%
df.mean(axis=1).plot()
